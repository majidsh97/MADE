# %% [markdown]
# # Data Exploration
#
# In this notebook describe your data exploration steps.

# %% [markdown]
# ## Install dependencies

# %%
# %pip install pandas
# %pip install 'SQLAlchemy==1.4.46'
# Out:
# ...
#
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...
#
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Load data

# %%
import pandas as pd

df = pd.read_sql_table('trainstops', 'sqlite:///data.sqlite')

# %% [markdown]
# ### Look at the first rows

# %%
df.head(10)
# Out:
#     EVA_NR DS100            IFOPT                             NAME  Verkehr  \
# 0  8002551  AELB   de:02000:11943               Hamburg Elbbrücken       RV
# 1  8001944  TETN             None                    Eutingen Nord       RV
# 2  8003074   MIA             None                  Ingolstadt Audi       RV
# 3  8001723  HEBA             None         Einbeck Otto-Hahn-Straße       RV
# 4  8004371   KRO             None            Nörvenich-Rommelsheim  nur DPN
# 5  8010340  DSTR             None          Straßgräbchen-Bernsdorf  nur DPN
# 6  8001510  TDSA  de:08237:8009:2                 Dornstetten-Aach       RV
# 7  8001966  MFOL   de:09187:90183                       Feldolling  nur DPN
# 8  8002060  FFGG   de:06412:11500  Frankfurt(Main)-Gateway Gardens       RV
# 9  8002535  EOBG    de:05962:3517                Halver-Oberbrügge       RV
#
#       Laenge     Breite             Betreiber_Name  Betreiber_Nr Status
# ...

# %% [markdown]
# ### Data exploration
# Print some basic information about the data. Your data exploration would continue here.

# %%
df.info()

df['Status'].unique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6519 entries, 0 to 6518
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   EVA_NR          6519 non-null   int64
#  1   DS100           6519 non-null   object
#  2   IFOPT           6512 non-null   object
#  3   NAME            6519 non-null   object
#  4   Verkehr         6519 non-null   object
#  5   Laenge          6519 non-null   float64
#  6   Breite          6519 non-null   float64
#  7   Betreiber_Name  6517 non-null   object
#  8   Betreiber_Nr    5395 non-null   float64
#  9   Status          24 non-null     object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 509.4+ KB
# array(['neu', None], dtype=object)

# %%
Lfd. Nummer 
11110
READONLY
INTEGER
 
Name des Flughafens 
Pocono Mountains Municipal Airport
READONLY
TEXT
 
Ort 
Mount Pocono
READONLY
TEXT
 
Land 
United States
READONLY
TEXT
 
IATA 
0
READONLY
TEXT
 
ICAO 
KMPO
READONLY
TEXT
 
Latitude 
41.13750076
READONLY
REAL
 
Longitude 
-75.37889862
READONLY
REAL
 
Altitude 
584
READONLY
# Out:
#   Cell In[3], line 6
#     Name des Flughafens
#          ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
x = pd.read_csv('/home/cip/ce/ix05ogym/Majid/MADE/exercises/rhein-kreis-neuss-flughafen-weltweit.csv',delimiter=';')
x[['Lfd. Nummer', 'Name des Flughafens', 'Ort', 'Land', 'IATA', 'ICAO',
       'Latitude', 'Longitude', 'Altitude']]
# Out:
#       Lfd. Nummer               Name des Flughafens        Ort          Land  \
# 0            8703                 Barberton Airport  Barberton  South Africa
# 1             330          Jena-Schöngleina Airport       Jena   Deutschland
# 2           13493                   COLNIZA Airport    COLNIZA        Brazil
# 3            1165      Kigali International Airport     Kigali        Rwanda
# 4           10723           Elsenthal Grafe Airport  Elsenthal   Deutschland
# ...           ...                               ...        ...           ...
# 7842         1519            Cagliari Elmas Airport   Cagliari         Italy
# 7843         1522          Torino-Aeritalia Airport      Turin         Italy
# 7844         1528  Genoa Cristoforo Colombo Airport      Genoa         Italy
# 7845         1532     Piacenza San Damiano Air Base   Piacenza         Italy
# 7846         1537                   Cervia Air Base     Cervia         Italy
#
# ...
